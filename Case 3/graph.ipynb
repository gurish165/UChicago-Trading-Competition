# %%
stocks = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
price_pct_df.plot(y=stocks, subplots=True, layout=(3,3), figsize=(15,15))
plt.savefig("price_data.png")

# %%
import pandas as pd
price_df = pd.read_csv('Acutal Testing Data.csv',index_col=0)
price = pd.read_csv('Acutal Testing Data.csv',index_col=0).to_numpy()

a_df1 = pd.read_csv('Predicted Testing Data Analyst 1.csv').to_numpy()
a_df2 = pd.read_csv('Predicted Testing Data Analyst 2.csv').to_numpy()
a_df3 = pd.read_csv('Predicted Testing Data Analyst 3.csv').to_numpy()

print(price[1][:])
price_df.head()
# Out:
# [ 144.9355746   227.8822077   145.0008114    78.89796435  139.7772862
#    33.60813051  172.1014887   305.0866483  3101.989323  ]
#             A           B           C          D           E          F  \
# 0  141.964897  226.352949  146.484337  77.539808  134.944262  32.982797
# 1  144.935575  227.882208  145.000811  78.897964  139.777286  33.608131
# 2  144.437134  234.666980  149.455145  81.378646  137.287929  33.521216
# 3  139.034096  231.480569  146.563009  83.680871  140.464937  32.373154
# 4  141.213983  233.275829  147.956318  79.816857  134.809211  31.813596
#
#             G           H            I
# 0  167.440304  297.091832  3091.003490
# 1  172.101489  305.086648  3101.989323
# 2  173.138616  304.388169  3134.173443
# 3  166.264334  300.779456  3122.525940
# 4  167.837537  312.957644  3134.811377

# %%
import numpy as np
np.zeros(9).shape
# Out:
# (9,)
